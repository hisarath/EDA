# %%
import pandas as pd

# %%
data=pd.read_csv("https://raw.githubusercontent.com/hisarath/EDA/main/cleaned%20data.csv")

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
data.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 10835     4.5       38  53000.0      5000  Free    0.0       Everyone
# 10836     5.0        4      3.6       100  Free    0.0       Everyone
# 10837     NaN        3      9.5      1000  Free    0.0       Everyone
# 10838     4.5      114      NaN      1000  Free    0.0     Mature 17+
# 10839     4.5   398307  19000.0  10000000  Free    0.0       Everyone
#
#                   Genres Last Updated         Current Ver         Android Ver  \
# ...

# %%
data.sample(10)
# Out:
#                                                 App             Category  \
# 2596                    SayHi Chat, Meet New People               SOCIAL
# 5208                                     ai.Bot Box         PRODUCTIVITY
# 10611             Clearwater, FL - weather and more              WEATHER
# 2669   Shrimp skin shopping: spend less, buy better             SHOPPING
# 4787                        X-ray scanner simulator               FAMILY
# 7289                          CG Yojna & Jansampark               FAMILY
# 3697                                   video player        VIDEO_PLAYERS
# 5451                    WiFi Access Point (hotspot)        COMMUNICATION
# 3830                               Yandex.Transport  MAPS_AND_NAVIGATION
# 633                           Spine- The dating app               DATING
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 2596      4.2   423105      NaN  10000000  Free    0.0     Mature 17+
# ...

# %%
data.shape
# Out:
# (10840, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  Day             10840 non-null  int64
#  14  Month           10840 non-null  int64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
data.describe().T
# Out:
#             count          mean           std  min     25%       50%  \
# Rating     9366.0  4.191757e+00  5.152189e-01  1.0     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06  0.0    38.0    2094.0
# Size       9145.0  3.509740e+04  9.951874e+04  1.0     5.6   15000.0
# Installs  10840.0  1.546434e+07  8.502936e+07  0.0  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01  0.0     0.0       0.0
# Day       10840.0  1.560904e+01  9.561621e+00  1.0     6.0      16.0
# Month     10840.0  6.422325e+00  2.578388e+00  1.0     5.0       7.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     54775.5  7.815831e+07
# Size        34000.0  1.020000e+06
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# Day            24.0  3.100000e+01
# Month           8.0  1.200000e+01

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Day', 'Month'],
#       dtype='object')

# %%
#To check the duplicates
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10835    False
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# Length: 10840, dtype: bool

# %%
data[data.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
#What function can be used to check particlular row ?

# %%
data[data["App"].duplicated()]
# Out:
#                                       App       Category  Rating  Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2    80805
# 236                                   Box       BUSINESS     4.2   159872
# 239                    Google My Business       BUSINESS     4.4    70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 261             join.me - Simple Meetings       BUSINESS     4.0     6989
# ...                                   ...            ...     ...      ...
# 10714                  FarmersOnly Dating         DATING     3.0     1145
# 10719  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10729                         FP Notebook        MEDICAL     4.5      410
# 10752      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10767                                AAFP        MEDICAL     3.8       63
#
#           Size  Installs  Type  Price Content Rating         Genres  \
# ...

# %%
#To drop
data=data.drop_duplicates(subset=["App"], keep="first")

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data.shape
# Out:
# (9659, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9659 entries, 0 to 10839
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   int64
#  6   Type            9658 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     9657 non-null   object
#  13  Day             9659 non-null   int64
#  14  Month           9659 non-null   int64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.2+ MB

# %%
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Day', 'Month']

# %%
categorical_features = [feature for feature in data.columns if data[feature].dtype == 'O']

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
#TO get the value count for particlular parameter
data["Type"].value_counts()
# Out:
# Free    8902
# Paid     756
# Name: Type, dtype: int64

# %%
#To get the value count in percentage
data["Type"].value_counts(normalize=True)
# Out:
# Free    0.921723
# Paid    0.078277
# Name: Type, dtype: float64

# %%
data["Type"].value_counts(normalize=True)*100
# Out:
# Free    92.172292
# Paid     7.827708
# Name: Type, dtype: float64

# %%
#To get a value count of every parameter
#1.Count plot

# %%
for col in categorical_features:
    print(f"{col}:{data[col].value_counts(normalize=True)*100}")
    print("=============================================")
# Out:
# App:Photo Editor & Candy Camera & Grid & ScrapBook    0.010353
# Tic Tac CK                                        0.010353
# INFAMY RO                                         0.010353
# CK Call NEW                                       0.010353
# Ck Coif                                           0.010353
#                                                     ...
# Bike Race Free - Top Motorcycle Racing Games      0.010353
# Dance School Stories - Dance Dreams Come True     0.010353
# 3D Bowling                                        0.010353
# Mind Games Pro                                    0.010353
# iHoroscope - 2018 Daily Horoscope & Astrology     0.010353
# Name: App, Length: 9659, dtype: float64
# ...
# Category:FAMILY                 18.966767
# GAME                    9.928564
# TOOLS                   8.561963
# BUSINESS                4.348276
# MEDICAL                 4.089450
# PERSONALIZATION         3.892743
# PRODUCTIVITY            3.872036
# ...

# %%
sns.countplot(x=data["Type"])
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
sns.countplot(x=data["Content Rating"])
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
sns.countplot(x=data["App"])
# Out:
# <Axes: xlabel='App', ylabel='count'>
# Error in callback <function flush_figures at 0x7f2eb97e8a60> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.9/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
# ...

# %%
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
category = [ 'Type', 'Content Rating']
for i in range(0, len(category)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=data[category[i]],palette="Set2")
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
#kde plot for numerical_features

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'Day', 'Month']

# %%
sns.kdeplot(data["Price"])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.kdeplot(data["Reviews"])
# Out:
# <Axes: xlabel='Reviews', ylabel='Density'>

# %%
sns.kdeplot(data["Rating"])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
#Conclusion:
#If the variate it catagorical we can make count plot
#If the variate is numerical we can make distributuion plot

# %%
#For multivariate analysis
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=data[numeric_features[i]],shade=True, color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
#Distribution Plot
sns.distplot(data["Reviews"])
# Out:
# <Axes: xlabel='Reviews', ylabel='Density'>

# %%
sns.distplot(data["Rating"])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
#To get hist plot alone
plt.hist(data["Reviews"])
# Out:
# (array([9.615e+03, 3.000e+01, 5.000e+00, 3.000e+00, 0.000e+00, 2.000e+00,
#         0.000e+00, 1.000e+00, 2.000e+00, 1.000e+00]),
#  array([       0.        ,  7815830.6       , 15631661.2       ,
#         23447491.8       , 31263322.4       , 39079153.        ,
#         46894983.59999999, 54710814.2       , 62526644.8       ,
#         70342475.39999999, 78158306.        ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["Rating"])
# Out:
# (array([  17.,   18.,   39.,   73.,  132.,  439.,  833., 1493., 3450.,
#         1702.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
#To get hist plot alone
plt.hist(data["Rating"])
plt.show()

# %%
#Univariate Analysis

#To check popular categorey in the app

# %%
data["App"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='App'>

# %%
data["App"].value_counts().plot.pie(y=data["App"])
# Out:
# <Axes: ylabel='App'>

# %%
data["Type"].value_counts().plot.pie(y=data["Type"])
# Out:
# <Axes: ylabel='Type'>

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Most popular category in the "Category"
data["Category"].value_counts().plot.pie(y=data["Category"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Category'>

# %%
#To get top 10 category value count
data["Category"].value_counts()[:10]
# Out:
# FAMILY             1832
# GAME                959
# TOOLS               827
# BUSINESS            420
# MEDICAL             395
# PERSONALIZATION     376
# PRODUCTIVITY        374
# LIFESTYLE           369
# FINANCE             345
# SPORTS              325
# Name: Category, dtype: int64

# %%
#Top 10 most popular category in the Category using pieplot
data["Category"].value_counts()[:10].plot.pie(y=data["Category"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Category'>

# %%
df_cat=data["Category"].value_counts()[:10]

# %%
category = pd.DataFrame(data['Category'].value_counts())        #Dataframe of apps on the basis of category
category.rename(columns = {'Category':'Count'},inplace=True)

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df_cat, y ='Count',data = category[:10],palette='hls')
plt.title('Top 10 App categories')
plt.xticks(rotation=90)
plt.show()

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
#Which category has largest no of installations

# %%
data.groupby(["Category"])["Installs"]

# %%
data.groupby(["Category"])["Installs"].sum()
# Out:
# Category
# ART_AND_DESIGN           114338100
# AUTO_AND_VEHICLES         53130211
# BEAUTY                    27197050
# BOOKS_AND_REFERENCE     1665969576
# BUSINESS                 697164865
# COMICS                    44981150
# COMMUNICATION          11038276251
# DATING                   140926107
# EDUCATION                352952000
# ENTERTAINMENT           2113660000
# EVENTS                    15973161
# FAMILY                  4427941505
# FINANCE                  455348734
# FOOD_AND_DRINK           211798751
# GAME                   13878924415
# HEALTH_AND_FITNESS      1144022512
# HOUSE_AND_HOME            97212461
# LIBRARIES_AND_DEMO        52995910
# LIFESTYLE                503823539
# MAPS_AND_NAVIGATION      503281890
# MEDICAL                   38193177
# NEWS_AND_MAGAZINES      2369217760
# PARENTING                 31521110
# PERSONALIZATION         1532494782
# PHOTOGRAPHY             4649147655
# PRODUCTIVITY            5793091369
# ...

# %%
data.groupby(["Category"])["Installs"].sum().sort_values(ascending=False)
# Out:
# Category
# GAME                   13878924415
# COMMUNICATION          11038276251
# TOOLS                   8001771915
# PRODUCTIVITY            5793091369
# SOCIAL                  5487867902
# PHOTOGRAPHY             4649147655
# FAMILY                  4427941505
# VIDEO_PLAYERS           3926902720
# TRAVEL_AND_LOCAL        2894887146
# NEWS_AND_MAGAZINES      2369217760
# ENTERTAINMENT           2113660000
# BOOKS_AND_REFERENCE     1665969576
# PERSONALIZATION         1532494782
# SHOPPING                1400348785
# HEALTH_AND_FITNESS      1144022512
# SPORTS                  1096474498
# BUSINESS                 697164865
# LIFESTYLE                503823539
# MAPS_AND_NAVIGATION      503281890
# FINANCE                  455348734
# WEATHER                  361100520
# EDUCATION                352952000
# FOOD_AND_DRINK           211798751
# DATING                   140926107
# ART_AND_DESIGN           114338100
# HOUSE_AND_HOME            97212461
# ...

# %%
data.groupby(["Category"])["Installs"].sum().sort_values(ascending=False).reset_index()#converted into data frame
# Out:
#                Category     Installs
# 0                  GAME  13878924415
# 1         COMMUNICATION  11038276251
# 2                 TOOLS   8001771915
# 3          PRODUCTIVITY   5793091369
# 4                SOCIAL   5487867902
# 5           PHOTOGRAPHY   4649147655
# 6                FAMILY   4427941505
# 7         VIDEO_PLAYERS   3926902720
# 8      TRAVEL_AND_LOCAL   2894887146
# 9    NEWS_AND_MAGAZINES   2369217760
# 10        ENTERTAINMENT   2113660000
# 11  BOOKS_AND_REFERENCE   1665969576
# 12      PERSONALIZATION   1532494782
# 13             SHOPPING   1400348785
# 14   HEALTH_AND_FITNESS   1144022512
# 15               SPORTS   1096474498
# 16             BUSINESS    697164865
# 17            LIFESTYLE    503823539
# 18  MAPS_AND_NAVIGATION    503281890
# 19              FINANCE    455348734
# 20              WEATHER    361100520
# 21            EDUCATION    352952000
# 22       FOOD_AND_DRINK    211798751
# 23               DATING    140926107
# ...

# %%
df_cat_installs=data.groupby(["Category"])["Installs"].sum().sort_values(ascending=False).reset_index()#converted into data frame

# %%
df2=df_cat_installs.head(10)#To get top 10

# %%
 #Bivariate analysis 
sns.barplot(x="Installs", y="Category", data=df2)
# Out:
# <Axes: xlabel='Installs', ylabel='Category'>

# %%
#To get much clear graph
plt.figure(figsize = (14,10))
sns.set_context("talk")
sns.set_style("darkgrid")

ax = sns.barplot(x = 'Installs' , y = 'Category' , data = df2 )
ax.set_xlabel('No. of Installations in Billions')
ax.set_ylabel('')
ax.set_title("Most Popular Categories in Play Store", size = 20)
# Out:
# Text(0.5, 1.0, 'Most Popular Categories in Play Store')

# %%
###What are the Top 5 most installed Apps in Each popular Categories ?

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
#Multi variate analysis

# %%
data.groupby(['Category','App'])['Installs'].sum().reset_index()
# Out:
#             Category                                                App  \
# 0     ART_AND_DESIGN                           350 Diy Room Decor Ideas
# 1     ART_AND_DESIGN    3D Color Pixel by Number - Sandbox Art Coloring
# 2     ART_AND_DESIGN                            AJ Styles HD Wallpapers
# 3     ART_AND_DESIGN  AJ Styles Wallpaper 2018 - AJ Styles HD Wallpaper
# 4     ART_AND_DESIGN                              Ai illustrator viewer
# ...              ...                                                ...
# 9654         WEATHER                                      Yahoo Weather
# 9655         WEATHER  Yahoo! Weather for SH Forecast for understandi...
# 9656         WEATHER                                     Yandex.Weather
# 9657         WEATHER                         weather - weather forecast
# 9658         WEATHER                     wetter.com - Weather and Radar
#
#       Installs
# 0        10000
# 1       100000
# 2         5000
# 3         1000
# 4       100000
# ...

# %%
dfa=data.groupby(['Category','App'])['Installs'].sum().reset_index()

# %%
dfa=dfa.sort_values('Installs',ascending=False)

# %%
dfa
# Out:
#                 Category                            App    Installs
# 9311    TRAVEL_AND_LOCAL             Google Street View  1000000000
# 6388  NEWS_AND_MAGAZINES                    Google News  1000000000
# 1145       COMMUNICATION  Skype - free IM & video calls  1000000000
# 9566       VIDEO_PLAYERS                        YouTube  1000000000
# 1181       COMMUNICATION             WhatsApp Messenger  1000000000
# ...                  ...                            ...         ...
# 9275    TRAVEL_AND_LOCAL       EG | Explore Folegandros           0
# 6020             MEDICAL                   EP Cook Book           0
# 3662             FINANCE                    Eu sou Rico           0
# 1797              FAMILY     Ain Arabic Kids Alif Ba ta           0
# 6471  NEWS_AND_MAGAZINES              Sweden Newspapers           0
#
# [9659 rows x 3 columns]

# %%
dfa[dfa.Category=='GAME'][:5]
# Out:
#      Category               App    Installs
# 4773     GAME    Subway Surfers  1000000000
# 4167     GAME  Candy Crush Saga   500000000
# 4628     GAME               Pou   500000000
# 4802     GAME      Temple Run 2   500000000
# 4580     GAME    My Talking Tom   500000000

# %%
dfa[dfa.Category=='COMMUNICATION'][:5]
# Out:
#            Category                            App    Installs
# 1145  COMMUNICATION  Skype - free IM & video calls  1000000000
# 1181  COMMUNICATION             WhatsApp Messenger  1000000000
# 1064  COMMUNICATION                       Hangouts  1000000000
# 1058  COMMUNICATION   Google Chrome: Fast & Secure  1000000000
# 1055  COMMUNICATION                          Gmail  1000000000

# %%
dfa[dfa.Category=='FAMILY'][:5]
# Out:
#      Category                            App   Installs
# 3333   FAMILY               Tom Loves Angela  100000000
# 3290   FAMILY              Talking Tom Cat 2  100000000
# 1976   FAMILY  Bitmoji – Your Personal Emoji  100000000
# 3289   FAMILY                Talking Tom Cat  100000000
# 3287   FAMILY         Talking Tom & Ben News  100000000

# %%
apps = ['GAME', 'COMMUNICATION', 'PRODUCTIVITY', 'SOCIAL' ]
sns.set_context("poster")
sns.set_style("darkgrid")

plt.figure(figsize=(40,30))

for i,app in enumerate(apps):
    df2 = dfa[dfa.Category == app]
    df3 = df2.head(5)
    plt.subplot(4,2,i+1)
    sns.barplot(data= df3,x= 'Installs' ,y='App' )
    plt.xlabel('Installation in Millions')
    plt.ylabel('')
    plt.title(app,size = 20)
    
plt.tight_layout()
plt.subplots_adjust(hspace= .3)

# %%
###How many apps are there on Google Play Store which get 5 ratings??

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510      8.7   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967      2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
rating=data.groupby(["App"])["Rating"].sum().sort_values(ascending=False).reset_index()

# %%
rating.Rating==5.0
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 9654    False
# 9655    False
# 9656    False
# 9657    False
# 9658    False
# Name: Rating, Length: 9659, dtype: bool

# %%
rating[rating.Rating==5.0]
# Out:
#                                                   App  Rating
# 0                           Comunidad De Fe Minitries     5.0
# 1                                     Tablet Reminder     5.0
# 2                               Noticias FC Barcelona     5.0
# 3    Superheroes, Marvel, DC, Comics, TV, Movies News     5.0
# 4                   DC N COMPANY ENTERTAINMENT RADIO!     5.0
# ..                                                ...     ...
# 266                     American Girls Mobile Numbers     5.0
# 267                                         daskal.eu     5.0
# 268                         Free coupons and vouchers     5.0
# 269                                      Bk Usha behn     5.0
# 270                           Asha Ek Hope - ALS/ MND     5.0
#
# [271 rows x 2 columns]

# %%
#Using multiple variable

# %%
rating2 = data.groupby(['Category','Installs', 'App'])['Rating'].sum().sort_values(ascending = False).reset_index()

# %%
rating2
# Out:
#             Category  Installs  \
# 0             FAMILY      1000
# 1             DATING       100
# 2             FAMILY        10
# 3             DATING       500
# 4            MEDICAL         5
# ...              ...       ...
# 9654           TOOLS       100
# 9655           TOOLS       100
# 9656        BUSINESS       100
# 9657           TOOLS       100
# 9658  ART_AND_DESIGN         0
#
#                                                    App  Rating
# 0                          CS & IT Interview Questions     5.0
# 1                              Online Girls Chat Group     5.0
# 2                                        Chronolink DX     5.0
# 3                                Spine- The dating app     5.0
# 4                                    Clinic Doctor EHr     5.0
# ...                                                ...     ...
# 9654                                         CG Wizard     0.0
# 9655  CG 3D Model Viewer: view 3D models interactively     0.0
# ...

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Day', 'Month'],
#       dtype='object')

# %%
###Which category app has the highest price

# %%
sns.scatterplot(data=data,y="Category",x='Price')
# Out:
# <Axes: xlabel='Price', ylabel='Category'>

# %%
###Which category app has the highest price

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=data,y="Category",x='Price')
# Out:
# <Axes: xlabel='Price', ylabel='Category'>

# %%
###Which Category app users are reviewing the most ?

# %%
ratings3=data.groupby(['App', 'Category'])['Reviews'].sum().sort_values(ascending = False).reset_index()

# %%
ratings3
# Out:
#                                            App             Category   Reviews
# 0                                     Facebook               SOCIAL  78158306
# 1                           WhatsApp Messenger        COMMUNICATION  69119316
# 2                                    Instagram               SOCIAL  66577313
# 3     Messenger – Text and Video Chat for Free        COMMUNICATION  56642847
# 4                               Clash of Clans                 GAME  44891723
# ...                                        ...                  ...       ...
# 9654                   Cypress College Library  BOOKS_AND_REFERENCE         0
# 9655                             Cyborg AX-001                 GAME         0
# 9656                                Kiosque CD     TRAVEL_AND_LOCAL         0
# 9657                              EP Cook Book              MEDICAL         0
# 9658                        Forest Crossing AH              MEDICAL         0
#
# [9659 rows x 3 columns]

# %%
data.groupby("Category").agg({"Installs":"sum","Reviews":"sum"}).reset_index()
# Out:
#                Category     Installs    Reviews
# 0        ART_AND_DESIGN    114338100    1419203
# 1     AUTO_AND_VEHICLES     53130211    1163666
# 2                BEAUTY     27197050     396240
# 3   BOOKS_AND_REFERENCE   1665969576   16721314
# 4              BUSINESS    697164865    9890245
# 5                COMICS     44981150    2342071
# 6         COMMUNICATION  11038276251  285811368
# 7                DATING    140926107    3623544
# 8             EDUCATION    352952000   13364148
# 9         ENTERTAINMENT   2113660000   34762650
# 10               EVENTS     15973161     161018
# 11               FAMILY   4427941505  143825488
# 12              FINANCE    455348734   12662106
# 13       FOOD_AND_DRINK    211798751    6325028
# 14                 GAME  13878924415  622298709
# 15   HEALTH_AND_FITNESS   1144022512   21361355
# 16       HOUSE_AND_HOME     97212461    1929847
# 17   LIBRARIES_AND_DEMO     52995910     906831
# 18            LIFESTYLE    503823539   11832671
# ...

# %%
data.groupby('Type').agg({'Installs':sum})
# Out:
#          Installs
# Type
# Free  75065572646
# Paid     57364881

# %%
data.groupby('Type').agg({'Installs':sum}).plot.pie(y='Installs')
# Out:
# <Axes: ylabel='Installs'>

# %%
data.value_counts('Type').plot.pie(y='Type')
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(1,2,figsize=(20,7))
data.value_counts('Type').plot.pie(y='Type',startangle=90, explode=(0.2,0), title='Percentage of the Free App and Paid App', legend=False, autopct='%.2f', ax=ax[0])
ax[0].set(ylabel='Type of Apps')
data.groupby('Type').agg({'Installs':sum}).plot.pie(y='Installs', startangle=90, explode=(0.2,0), title='Percentage of Installs Number for Free App and Paid App', legend=False, autopct='%.2f', ax=ax[1])
# Out:
# <Axes: title={'center': 'Percentage of Installs Number for Free App and Paid App'}, ylabel='Installs'>

# %%
#To plot box plot for comparison
plt.figure(figsize=(10,10))
sns.boxplot(x="Installs",y="Rating",data=data)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x="Category",y="Rating",data=data)
plt.xticks(size=15,rotation=90)
plt.show()

# %%
###Which Category are of largest size ?

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'Day', 'Month'],
#       dtype='object')

# %%
plt.figure(figsize=(15,15))
plt.xticks(rotation = 90)
sns.barplot('Category','Size',data=data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-165-225a8548a5ed> in <cell line: 3>()
#       1 plt.figure(figsize=(15,15))
#       2 plt.xticks(rotation = 90)
# ----> 3 sns.barplot('Category','Size',data=data)
#       4 plt.show()
#
# TypeError: barplot() got multiple values for argument 'data'

# %%
plt.subplots(figsize=(20,10))
freq= pd.Series()
freq=data['year'].value_counts()
freq.plot()
plt.xlabel("Dates")
plt.ylabel("Number of updates")
plt.title("Time series plot of Last Updates")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
